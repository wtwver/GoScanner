# %%
# target="192.168.0.103"
# target = "scanme.nmap.org"
# target="demo.testfire.net"
target ="testphp.vulnweb.com"


crawl_depth=3
fuzz_recur=True
# wordlist="common-api-endpoints-mazen160.txt"
wordlist="big.txt"
# wordlist="vlunweb.txt"

def setting():
    # !docker volume create result
    # !docker run -i -v result:/tmp alpine sh -c "echo $target"
    # !docker run -i -v /fyp:/tmp alpine sh -c "mkdir /tmp/$target 2>/dev/null && chmod 777 /tmp/$target"
        
    # !mkdir ~/fyp/$target
    # !cd /fyp/$target 
    # !pwd


def acrawler():
    # !docker run -i --rm -v result:/tmp snowsecurity/photon -u $target --wayback -l $crawl_depth -t 10 -o /tmp/photon
    # !docker run -i -v result:/tmp alpine sh -c "echo $target"
    
    # !docker run -v /fyp/$target:/tmp --rm -i wtwver/hakrawler bash -c "hakrawler -url $target -depth $crawl_depth -plain -wayback > /tmp/hakrawler.txt"
    # !ls /fyp/$target && cat hakrawler.txt | tee acrawler.txt
    # !ls /fyp/$target


def pcrawler():
    # !docker run -i --rm -v /fyp/$target:/tmp heywoodlh/tomnomnom-tools:latest ash -c "echo $target | waybackurls | sort -u | tee /tmp/pcrawler.txt "

def afuzzer():
    # !docker run -i --entrypoint sh --rm -v /fyp/$target:/tmp -v /fyp/wordlist:/wordlist trickest/ffuf -c "ls /tmp"
    # !docker run -i --rm -v /fyp/$target:/tmp -v /fyp/wordlist:/wordlist trickest/ffuf -ac -u http://$target/FUZZ -w /wordlist/$wordlist -of json -o /tmp/ffuf.json # -recursion 
    # !cd /fyp/{target} && cat ffuf.json | jq .results[].url | awk -F "\"" '{{print $$2}}' | tee afuzzer.txt
    # !cat /fyp/{target}/ffuf.txt | awk -F "\"" '{{print $$2}}' 

def aparam():
    # arjun have problem in output file 

    # !cd /fyp/{target} && cat afuzzer.txt | grep -v -E "\.js|\.ico|\.txt|favicon" | tee afuzzer_clean.txt

    # !docker run -v /fyp/$target:/tmp --rm -i wtwver/arjun /Arjun/arjun.py -i /tmp/afuzzer_clean.txt -o /tmp/aparam.json
    # !cd /fyp/{target} && cat aparams.json

def pparam():
    # !docker run -v /fyp/$target:/tmp -i --rm trickest/paramspider -d {target} --level high -o /tmp/pparam.txt
    # !cd /fyp/{target} && cat pparam.txt

def CVE():
    # !docker run --rm -i -v /fyp/$target:/tmp --entrypoint sh projectdiscovery/nuclei -c "cat /tmp/afuzzer.txt | ./nuclei -t / -update-templates -silent"
    # -c \"cat /tmp/pcrawl.txt && ./nuclei -t / -update-templates\"

def XSS(): 
    # add output file
    # !docker run -v /fyp/$target:/tmp -i --rm hahwul/dalfox /app/dalfox file /tmp/pparam.txt --silence



def server():
    # !docker run --rm -i -v /fyp:/var/www:ro -p 9999:9999 trinitronx/python-simplehttpserver


setting()
# acrawler()
# pcrawler()
# afuzzer()
# aparam()
pparam()
# CVE()
XSS()
# Out:
#          ___                               _    __
#         / _ \___ ________ ___ _  ___ ___  (_)__/ /__ ____
#        / ___/ _ `/ __/ _ `/  ' \(_-</ _ \/ / _  / -_) __/
#       /_/   \_,_/_/  \_,_/_/_/_/___/ .__/_/\_,_/\__/_/
#                                   /_/
#
#                             - coded with <3 by Devansh Batham
#
#
# http://testphp.vulnweb.com/showimage.php?file=./pictures/7.jpg&size=FUZZ
# http://testphp.vulnweb.com:80/categories.php/listproducts.php?cat=FUZZ
# http://testphp.vulnweb.com/artists.php?artist=FUZZ
# http://testphp.vulnweb.com:80/listproducts.php?cat=FUZZ
# http://testphp.vulnweb.com/showimage.php?file=8&size=FUZZ
# http://testphp.vulnweb.com:80/admin/?C=S;O=FUZZ
# http://testphp.vulnweb.com:80/product.php?pic=FUZZ
# http://testphp.vulnweb.com:80/comment.php?aid=FUZZ
# http://testphp.vulnweb.com/listproducts.php?cat=FUZZ
# http://testphp.vulnweb.com:80/search.php?test=FUZZ
# http://testphp.vulnweb.com/showimage.php?file=./pictures/2.jpg&size=FUZZ
# ...

# %%
# %%bash
# target=321
# echo $target
# echo 123
# # exec(result)
#
#
# # !docker run -i --rm -v result:/tmp --entrypoint sh trickest/ffuf -c "wget https://raw.githubusercontent.com/danielmiessler/SecLists/master/Discovery/Web-Content/common-api-endpoints-mazen160.txt && ffuf -u http://juiceshop321.herokuapp.com/FUZZ -w common-api-endpoints-mazen160.txt | tee /tmp/3.txt"
#
# # exec(acrawler)
#
# # exec(pcrawler)
# # exec(afuzzer)
#
# # exec(heuristic)
# # exec(hakrawler)
# # exec(rm_pcrawler_js)
#
# # !docker run --rm -v result:/tmp ubuntu bash -c "cat /tmp/pcrawl.txt | grep -v -E '\.js|\.md' | sort -u | tee /tmp/pcrawl_nojs.txt"
# Out:
# 321
# 123

# %%
# !docker run -i -v /fyp/:/tmp alpine sh -c "apk add wget && wget https://raw.githubusercontent.com/danielmiessler/SecLists/master/Discovery/Web-Content/big.txt -O /tmp/wordlist/big.txt"

# %%
# %%bash
#
#
# ls
# docker run -i -v result:/tmp alpine sh -c "echo 321321"
# ls
# Out:
# crawler-v1.ipynb
# crawler-v2.ipynb
# crawler-v2.sh
# OIDCSecurity_1
# OIDCSecurity_1.pdf
# 321321
